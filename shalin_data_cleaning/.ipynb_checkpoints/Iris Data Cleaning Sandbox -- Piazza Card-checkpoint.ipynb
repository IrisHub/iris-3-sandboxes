# %% [markdown]
# # Welcome to the Iris Data Cleaning Sandbox for Piazza Card
#
# This file provides you a framework with which you can examine data. Here, I provide you with some starter functions along with a guide for some of the things you should be looking for during your research. Duplicate this notebook wherever you need it

# %%
# You probably won't need much more than this
import json
import os
import re
import requests
import time
from bs4 import BeautifulSoup
from datetime import datetime

# Optional statistics
import numpy as np
import seaborn as sns
import statistics
import matplotlib.pyplot as plt
from scipy import stats

! pip3 install piazza-api
# Out:
# ...
#   Created wheel for piazza-api: filename=piazza_api-0.11.0-py3-none-any.whl size=12216 sha256=93b8baac13dd7a82feabacf0f3ba42f4d52192e0468465b08cdb7314ba02d58a
#   Stored in directory: /Users/shalinshah/Library/Caches/pip/wheels/ea/00/c1/3e4a5ccf144f10e874228335b9864afd39fced7d5a892c3c4e
# Successfully built piazza-api
# ...

# %%
# HERE'S WHERE YOU CAN DO ALL OF YOUR WORK!
# USE THE SIMPLE FUNCTIONS IN THE LATER SECTIONS IF YOU WANT

data = get_api_file("./berkeley_classes.json")["result"]

classes, class_names, class_ids, professors = [], [], [], []
for term in data:
    try:
        classes.append([term['cn'] for time in term["terms"] if (time == ("Fall 2020") and term["cn"] != None)])
        class_names.append([term['n'] for time in term["terms"] if (time == ("Fall 2020") and term["cn"] != None)])
        class_ids.append([term['terms']['Fall 2020']['id'] for time in term["terms"] if (time == ("Fall 2020") and term["cn"] != None)])
        professors.append([term['terms']['Fall 2020']['prof'] for time in term["terms"] if (time == ("Fall 2020") and term["cn"] != None)])
    except:
        continue

classes, class_names, class_ids, professors = [i for s in classes for i in s], [i for s in class_names for i in s], [i for s in class_ids for i in s], [i for s in professors for i in s]

json_data = json.dumps([{'class': cl, 'full_name': nm, 'class_id': cl_id, 'professor': pr, 'term': "Fall 2020"} for cl, nm, cl_id, pr in zip(classes, class_names, class_ids, professors)], indent=2)
print(json_data)
# Out:
# [
#   {
#     "class": "EECS 101",
#     "full_name": "EECS Center for Student Affairs",
#     "class_id": "kdtcwa91u6m46s",
#     "professor": "None",
#     "term": "Fall 2020"
#   },
#   {
#     "class": "MATH 110",
#     "full_name": "Linear Algebra",
#     "class_id": "kcz7n0fk1ps4yv",
#     "professor": "Zvezdelina Stankova",
#     "term": "Fall 2020"
#   },
#   {
#     "class": "MSSE TEST",
#     "full_name": "msse test",
#     "class_id": "k4bsojehtrq64x",
#     "professor": "Rocky Little",
#     "term": "Fall 2020"
#   },
#   {
#     "class": "MCB 140",
#     "full_name": "General Genetics",
#     "class_id": "kdz103x5krx3jv",
#     "professor": "Douglas Koshland",
#     "term": "Fall 2020"
#   },
#   {
#     "class": "EE 105",
#     "full_name": "Microelectronic Devices and Circuits",
#     "class_id": "ke1qafm27ca6tv",
#     "professor": "Kieran Peleaux, Clark Nguyen, Qiutong Jin, David Au",
#     "term": "Fall 2020"
#   },
#   {
#     "class": "SOC WEL 114",
# ...

# %%
from piazza_api import Piazza



p = Piazza()
p.user_login()
# Out:
# Email: shalins@berkeley.edu
# ········

# %%
class_ids
# Out:
# ['kdtcwa91u6m46s',
#  'kcz7n0fk1ps4yv',
#  'k4bsojehtrq64x',
#  'kdz103x5krx3jv',
#  'ke1qafm27ca6tv',
#  'k9oht19rtfr5y',
#  'ke53xuwipd14xc',
#  'k9tezyc0yo236j',
#  'ka720nbvvip283',
#  'kaingcuacl23y2',
#  'ke3dwbmk1ma6rf',
#  'kaucp51443h5sd',
#  'kbd1uxr9q4o2nc',
#  'keafyt803mdg',
#  'kdauunovby9yx',
#  'kblbpmq9pmn2ln',
#  'ke9i0owryzz4zo',
#  'kboh8tm26ks2sm',
#  'ke4mgu70n7z5q4',
#  'kbsll0osl9r4cx',
#  'kbv6d9zppn51iv',
#  'kbvasui3yvh43s',
#  'kc556f4o88w4bw',
#  'kc5e2yxmc6u1vl',
#  'kc5e7vrccs3r9',
#  'kc5ew0472b75gw',
#  'kc9j1mn3pnakv',
#  'kc9wfmpkl4m1eq',
#  'kcb1wu1ndyn50v',
#  'kccadn8xrxf3fa',
#  'kcchr4dtwk56x',
#  'kcdz8i2ln5v5pc',
#  'kce0bemx3mr2de',
#  'kce0j0rolc62lo',
#  'kcgfdvmf4am1fw',
#  'kcmwa5g9hl12vh',
#  'kcmwi3fnwa57di',
#  'kcoznf8enpq4h',
#  'kcpb1twje6i4ul',
#  'kcprzmnr4ty2ek',
#  'kcqdaxvl5se7ld',
#  'kcqhiq3lkkj3rq',
#  'kctjmwetrs52c1',
#  'kcvhh9ph3s2341',
#  'kcvikpfz46522q',
#  'kcw62cof7bh4ps',
#  'kcw7guk6a4y412',
#  'kcw99ty7d1huz',
# ...

# %%
headers = {
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/javascript, */*; q=0.01',
    'CSRF-Token': 'WQRidDGncLvjx3Yr8kjc4XDf',
    'X-Requested-With': 'XMLHttpRequest',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36',
    'Content-Type': 'application/json',
    'Origin': 'https://piazza.com',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Dest': 'empty',
    'Referer': 'https://piazza.com/signup/berkeley',
    'Accept-Language': 'en-US,en;q=0.9',
}

params = (
    ('method', 'network.join'),
    ('aid', 'kemasud1mswm'),
)

data = '{"method":"network.join","params":{"email":"shalins@berkeley.edu","nids":["kdtcwa91u6m46s","kcz7n0fk1ps4yv","k4bsojehtrq64x","kdz103x5krx3jv","ke1qafm27ca6tv","k9oht19rtfr5y","ke53xuwipd14xc","k9tezyc0yo236j","ka720nbvvip283","kaingcuacl23y2","ke3dwbmk1ma6rf","kaucp51443h5sd","kbd1uxr9q4o2nc","keafyt803mdg","kdauunovby9yx","kblbpmq9pmn2ln","ke9i0owryzz4zo","kboh8tm26ks2sm","ke4mgu70n7z5q4","kbsll0osl9r4cx","kbv6d9zppn51iv","kbvasui3yvh43s","kc556f4o88w4bw","kc5e2yxmc6u1vl","kc5e7vrccs3r9","kc5ew0472b75gw","kc9j1mn3pnakv","kc9wfmpkl4m1eq","kcb1wu1ndyn50v","kccadn8xrxf3fa","kcchr4dtwk56x","kcdz8i2ln5v5pc","kce0bemx3mr2de","kce0j0rolc62lo","kcgfdvmf4am1fw","kcmwa5g9hl12vh","kcmwi3fnwa57di","kcoznf8enpq4h","kcpb1twje6i4ul","kcprzmnr4ty2ek","kcqdaxvl5se7ld","kcqhiq3lkkj3rq","kctjmwetrs52c1","kcvhh9ph3s2341","kcvikpfz46522q","kcw62cof7bh4ps","kcw7guk6a4y412","kcw99ty
print(response.json())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-8f8c4ec46879> in <module>
# ...

# %%
user_profile = p.get_user_profile()
# print(user_profile)

r = self.request(
    method="network.join",
    data={
        "from": "ClassSettingsPage",
        "add_students": student_emails
    },
    nid=None,
    nid_key="id"
)

eece210 = p.network("k5ndo70294q5fm")
eece210.get_post(962)
# Out:
# {'folders': ['logistics'],
#  'nr': 962,
#  'data': {'embed_links': []},
#  'created': '2020-05-26T04:23:10Z',
#  'bucket_order': 0,
#  'no_answer_followup': 1,
#  'change_log': [{'anon': 'no',
#    'uid': 'j6z6zrng7mk774',
#    'data': 'kanezca739t69x',
#    'v': 'all',
#    'type': 'create',
#    'when': '2020-05-26T04:23:10Z'},
#   {'anon': 'no',
#    'uid': 'j6z6zrng7mk774',
#    'data': 'kanf0823exd7lm',
#    'type': 'update',
#    'when': '2020-05-26T04:23:52Z'},
#   {'anon': 'no',
#    'uid': 'j6z6zrng7mk774',
#    'data': 'kanf0vckuuq6d',
#    'type': 'update',
#    'when': '2020-05-26T04:24:22Z'},
#   {'anon': 'stud',
#    'to': 'kanezca4e2z69v',
#    'type': 'followup',
#    'when': '2020-05-26T04:24:43Z',
#    'uid_a': 'a_0'},
#   {'anon': 'no',
#    'uid': 'j6z6zrng7mk774',
#    'to': 'kanezca4e2z69v',
#    'type': 'feedback',
#    'when': '2020-05-26T04:25:02Z'},
#   {'anon': 'stud',
#    'to': 'kanezca4e2z69v',
#    'type': 'followup',
# ...

# %% [markdown]
# # Appendix: Data Cleaning Guide and Functions
# ## Retrieving Data from a Data Source
#
# Most of the data you work with will be in JSON format. This kind of data is usually pretty easy to work with -- it's easy to read, nicely and neatly nested, and you've seen it everywhere. Here's a brief script that gives you a framework for extracting a JSON object as an API response.

# %%
def get_api_json(url, params={}):
    """Return the JSON object retrieved from a url with optional parameters"""
    try:
        obj = requests.get(url, params=params)
    except requests.exceptions.RequestException as e:
        return SystemExit(e)

    try:
        data = obj.json()
    except:
        data = json.loads(obj.text())
    
    return data

# %% [markdown]
# Sometimes the data you're looking for will be HTML data. This is true when we're dealing with a plain webscrape as opposed to an official or external-facing API. You shouldn't encounter these too often.

# %%
def get_api_html(url):
    """Return a BeautifulSoup object representing the HTML of a website"""
    try:
        obj = requests.get(url)
    except requests.exceptions.RequestException as e:
        return SystemExit(e)
    
    soup = BeautifulSoup(obj.content, 'html.parser')
    return soup

# %% [markdown]
# For `BeautifulSoup` you only really need to be concerned with one method -- the `find_all` function, which takes in a string or regular expressions and returns a list of all matches. For instance, `soup.find_all('h3')` returns a list of all `h3` tags in the HTML. Additionally, `soup.find_all(class_='desc_wrap_ck3')` returns a list of all items that match that `class`.

# %%
def get_api_file(file_path):
    """Return a JSON object representing a local JSON file"""    
    try:
        f = open(file_path,) 
        data = json.load(f) 
    except requests.exceptions.RequestException as e:
        return SystemExit(e)
    
    return data

# %% [markdown]
# ## REGular EXpressions
#
# A lot of times you'll need regex to filter out API results and clean entries dynamically. Regex is supplied to python via the `re` package. A guide to regular expressions can be found at https://www.regular-expressions.info/tutorial.html (the Bible for regex). If you need help with a particular regex just message Kanyes :)
#
# There are two functions in particular that you should know how to use -- `re.sub(pattern, str or func, target)` will search for a pattern within a target string and replace it, either with a static string or with a function that can take in the pattern match as an argument.
#
# For example, `re.sub(r'\(.*\)|\{.*\}', "", "hello, (world)")` will strip out anything in parantheses or brackets from the target string.
#
# Likewise, `re.sub(r'([^0-9])', lambda rgx: f"{rgx.group(1)}", "hello 123 world")` will extract anything that isn't a number (`^[0-9]`) from the target string and substitute the extraction back into the target string, so `"hello 123 world"` becomes `"hello  world"`.

# %% [markdown]
# ## Filtering and Modifying an API response
#
# Sometimes, the data within an API response isn't good enough itself -- we might need to add a temporary field in real-time as we're processing an API result. For instance, in the Yummly 28k dataset, we didn't have a flag for diet. While we're examining data and checking if it's good enough for a card, we need a way to create this new diet field within the response temporarily. The following functions allow us to do some basic filtering and modifying of a response.
#
# This is most useful when the API returns a collection or list of objects rather than just 1 object -- for instance, a recipes endpoint which returns 100 recipes or a concerts endpoint that returns 20 concerts.

# %% [markdown]
# Adding a temp field is simple enough -- just do something like:
# ```
# for result in data['results']:
#     result['new_field'] = function_or_value()
# ```
#
# Removing a field is also easy; use
# ```
# del data['field_to_be_removed']
# ```

# %%
def extract_field_from_list(l, field_name):
    """Given a list of dicts, extract a field from each dict"""
    return [e[field_name] for e in l]

def filter_list(l, boolexpr):
    """Filter a list based on a boolean expression"""
    return [e for e in l if boolexpr(e)]

def clean_list(l, regexpr):
    """Given a regex lambda function, clean a particular field in a list of dicts"""
    return [regexpr(e) for e in l]

# Example usage: 
# extract_field_from_list(data['recipes'], 'title')
# filter_list(data['recipes'], lambda recipe: recipe['rating'] > 3)
# clean_list(data['recipes'], lambda recipe: re.sub(r'([A-Za-z])', lambda rgx: f"{rgx.group(1)}", recipe['title']))

# %% [markdown]
# ## Analytics and Information
# Here are some basic functions that allow you to see the distribution of a certain field in the data. This can be helpful in testing how diverse an API response is, or testing the quality of the response.

# %%
def hist(vals):
    """Display a histogram for a list `vals` """
    mean_val = statistics.mean(vals)
    print(f"Mean value: {mean_val}")
    sns.set(color_codes=True)
    sns.distplot(vals)
    plt.show()

def count(vals):
    """Display a count plot for a list `vals` (categorical data)"""
    sns.set(color_codes=True)
    sns.countplot(vals)
    plt.show()

def percentile(l, item):
    """find the percentile of an item based on a list"""
    return stats.percentileofscore(l, item)

# %% [markdown]
# ## Save and Load
# Sometimes you may want to save an API response after you've modified it or load it again later. These functions let you do that.

# %%
def save(filename, data):
    """Saves a file in the current directory"""
    if not os.path.exists(filename):
        open(filename, 'w').close()
    
    with open(filename, 'r+') as f:
        try:
            f.seek(0)
            f.write(json.dumps(data, indent=4))
        except:
            f.seek(0)
            if type(data) == str:
                f.write(data)
            else:
                print("Invalid data type")
                return
        f.truncate()

def load(filename):
    with open(filename, 'r+') as f:
        try:
            f.seek(0)
            data = json.load(f)
        except:
            f.seek(0)
            data = f.read()
        return data
