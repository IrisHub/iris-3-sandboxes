# %% [markdown]
# # Welcome to the Iris Data Cleaning Sandbox!
#
# This file provides you a framework with which you can examine data. Here, I provide you with some starter functions along with a guide for some of the things you should be looking for during your research. Duplicate this notebook wherever you need it

# %%
# You probably won't need much more than this
import json
import os
import re
import requests
import time
from bs4 import BeautifulSoup
from datetime import datetime

# Optional statistics
import numpy as np
import seaborn as sns
import statistics
import matplotlib.pyplot as plt
from scipy import stats

# %%
# HERE'S WHERE YOU CAN DO ALL OF YOUR WORK!
# USE THE SIMPLE FUNCTIONS IN THE LATER SECTIONS IF YOU WANT

page_content = requests.get("https://www.wenxuecity.com/", verify=False).content
soup = BeautifulSoup(page_content, 'html.parser')
results = soup.select("div div ul li")
print(results)
# Out:
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# [<li class="selected"><a href="//www.wenxuecity.com/">首页</a></li>, <li><a href="//www.wenxuecity.com/news/">新闻</a></li>, <li><a href="//www.wenxuecity.com/news/photo/?utm_source=wxc&amp;utm_medium=navi&amp;utm_campaign=05242016">读图</a></li>, <li><a href="//bbs.wenxuecity.com/financenews/">财经</a></li>, <li><a href="//www.wenxuecity.com/edu/">教育</a></li>, <li><a href="//www.wenxuecity.com/home/">家居</a></li>, <li><a href="//www.wenxuecity.com/health/">健康</a></li>, <li><a href="//www.wenxuecity.com/cooking/">美食</a></li>, <li><a href="//www.wenxuecity.com/style/">时尚</a></li>, <li><a href="//www.wenxuecity.com/travel/">旅游</a></li>, <li><a href="//www.wenxuecity.com/video/">影视</a></li>, <li><a href="//blog.wenxuecity.com/">博客</a></li>, <li><a href="//groups.wenxuecity.com/">群组</a></li>, <li><a href="/yoyo/?act=list">悠游</a></li>, <li class="last"><a href="//bbs.wenxuecity.com/">论坛</a></li>, <li>
# <a href="/news/2020/08/27/9808438.html">
#                         他当面告诉王毅：中国的胁迫外交对加拿大无效                     </a>
# </li>, <li>
# <a class="adslink" href="https://home.dealsaving.com/">
#                         便宜！Ann Taylor全网高达5折, 打折区额外70% off!                        </a>
# </li>, <li>
# <a class="adslink" href="https://www.cardbenefit.com/search-credit-cards/?cardChoice=creditRating&amp;ccRating=good-credit&amp;introid=sapphire&amp;show=42&amp;src=wxc1">
#                         赶快申请蓝钻卡，开户送$750，旅游餐饮返2%!                     </a>
# </li>, <li>
# <a href="/news/2020/08/27/9808435.html">
#                         “香港人”若获诺贝尔和平奖？ 王毅：勿干涉中国内政                     </a>
# </li>, <li>
# <a href="/news/2020/08/27/9808433.html">
#                         美国国防部指责中国军队在南海发射导弹“破坏地区稳定”                     </a>
# </li>, <li>
# <a class="adslink" href="https://www.dealmoon.com/wxc1">
#                         罕见！La Mer豪送$452好礼，包含正装神奇面霜                     </a>
# </li>, <li>
# <a href="/news/2020/08/27/9808431.html">
#                         浙企高管被警方跨省询问至凌晨 两天后突然猝死                     </a>
# </li>, <li>
# <a href="/news/2020/08/27/9808427.html">
#                         中石油巨亏300亿，这家A股更离谱，半年巨亏270亿                     </a>
# </li>, <li>
# <a href="/news/2020/08/27/9808321.html">
#                         台湾网红“馆长”陈之汉深夜被人当街连开 3 枪                     </a>
# </li>, <li>
# <a class="adslink" href="https://home.dealsaving.com/view/50330">
#                         施华洛世奇最受欢迎的天鹅项链和耳环5折！低至$39!                        </a>
# </li>, <li>
# <a href="/news/2020/08/27/9808316.html">
#                         小鹏汽车登陆纽交所：市值已破百亿美元                     </a>
# </li>, <li>
# <a href="/news/2020/08/27/9808310.html">
#                         临危受命，TikTok 的新负责人是谁？                     </a>
# </li>, <li>
# <a href="/news/2020/08/27/9808298.html">
#                         成人展惊现“房思琪”情趣桌游，“吃相”太难看                     </a>
# </li>, <li>
# <a href="/news/2020/08/27/9807904.html">
#                         17岁“川普粉”枪杀抗议者 美国已如此分裂？                     </a>
# </li>, <li>
# <a class="adslink" href="https://home.dealsaving.com/view/50349">
#                         舒适又有气质! Express清仓区额外60% off低至$6!                        </a>
# </li>, <li>
# <a href="/news/2020/08/27/9807699.html">
#                         北京上空惊现“手指”云 网友：这是“神仙指路”吗？                     </a>
# </li>, <li>
# <a href="/news/2020/08/27/9807694.html">
#                         慈禧年轻美照刷屏 小伙手绘画竟引故宫考证 老专家都上当                     </a>
# </li>, <li>
# <a href="/news/2020/08/27/9807687.html">
#                         “虎妈”老公陷性骚扰丑闻：身为耶鲁知名教授的他做过什么                     </a>
# </li>, <li>
# <a href="/news/2020/08/27/9807670.html">
#                         共和党大会上宣誓入籍女子：没想到特朗普会参加                     </a>
# </li>, <li>
# <a class="adslink" href="https://www.dealmoon.com/wxc2">
#                         周生生金饰5折起！珍珠贝母、镂空雪花项链超美～                     </a>
# </li>, <li>
# <a href="/news/2020/08/27/9807649.html">
#                         台湾反共网红“馆长”突遭枪击 中多枪倒卧血泊                     </a>
# </li>, <li>
# <a href="/news/2020/08/27/9807639.html">
#                         王岐山隐身太久？曝其父为国民党军官 文章被翻炒                     </a>
# </li>, <li>
# <a href="/news/2020/08/27/9807610.html">
#                         彭斯提名演讲 轰拜登“中共啦啦队长”(视频)                     </a>
# </li>, <li>
# <a href="/news/2020/08/27/9807565.html">
#                         儿子惨遭枪击 黑人妈妈说话了 煽风点火的CNN傻眼了                     </a>
# </li>, <li>
# <a href="/news/2020/08/27/9807560.html">
#                         飓风“全怪兽模式”直扑美国 恐引致命暴潮150万人须撤离                     </a>
# </li>, <li>
# <a class="adslink" href="http://bbs.wenxuecity.com/advpost/3071.html">
#                         消除胸闷气短/头晕耳鸣, 就选美国 [心血通/益脑灵]                     </a>
# </li>, <li>
# <a href="/news/2020/08/27/9807545.html">
#                         习近平失两张王牌 李克强再遭重击                     </a>
# </li>, <li>
# <a href="/news/2020/08/27/9807523.html">
#                         美国社会的火药库：疫情、种族问题和武装民兵…                     </a>
# </li>, <li>
# <a href="/news/2020/08/27/9807507.html">
#                         拆除7.1亿的豪华中学：一次作妖、二次曝光、三杯自罚                     </a>
# </li>, <li>
# <a href="/news/2020/08/27/9807502.html">
#                         盲女杀人事件：被初恋挖眼后 拿斧头砍向丈夫                     </a>
# </li>, <li>
# <a class="adslink" href="https://www.dealmoon.com/wxc3">
#                         LOFT又开仓！泡泡袖开衫$8, 西服$20，这波别错过                     </a>
# </li>, <li>
# <a href="/news/2020/08/27/9807319.html">
#                         让NBA罢赛 奥巴马声援的黑人是谁？劣迹斑斑曾强奸                     </a>
# </li>, <li>
# <a href="/news/2020/08/27/9807297.html">
#                         沃尔玛证实 将与微软联手收购TikTok                     </a>
# </li>, <li>
# <a href="/news/2020/08/27/9807295.html">
#                         猛男影帝人设崩塌：曾给周润发写情书 婚后和男星同床                     </a>
# </li>, <li>
# <a href="/news/2020/08/27/9807250.html">
#                         川普共和党大会今晚演讲稿提前披露！火力全开！                     </a>
# </li>, <li>
# <a class="adslink" href="https://bbs.wenxuecity.com/bbs/advpost/2772.html">
#                         高中生居家必备 SAT/ACT/AP 线上刷题+解答                     </a>
# </li>, <li>
# <a href="/news/2020/08/27/9807229.html">
#                         实在扛不住了！美国第一间百货公司“吹熄灯号”                     </a>
# </li>, <li>
# <a href="/news/2020/08/27/9807228.html">
#                         陆媒评论人：小心美军！川普或正酝酿“危险动作”                     </a>
# </li>, <li><a class="adslink" href="http://cn.dealam.com/?ref=wxrst4406346674">疫情下美国人开始存钱！储蓄率创33%历史新高！</a></li>, <li><a href="/news/2020/08/27/9807200.html">涉嫌侮辱前中共领导人 知名女星为何敢这样做</a></li>, <li><a href="/news/2020/08/27/9807165.html">传TikTok与微软可能在48小时内达交易 交易规模达…</a></li>, <li><a class="adslink" href="http://pubads.g.doubleclick.net/gampad/clk?id=112296481&amp;iu=/30613721/homepage_news">SpaceX成功跳跃！火星旅行不再是梦，科技正在改变生活</a></li>, <li><a href="/news/2020/08/27/9807157.html">当年的异见艺术家华涌：逃亡至国外仍被“穷追猛打”</a></li>, <li><a href="/news/2020/08/27/9807138.html">盲人维权律师陈光诚：中共是人类公敌(视频/中文字幕)</a></li>, <li><a href="/news/2020/08/27/9806556.html">威州骚乱：17岁白男射杀2示威者 持枪淡定走向警察</a></li>, <li><a href="/news/2020/08/27/9806510.html">中南海开座谈会，习近平究竟要如何转危为机？</a></li>, <li><a class="adslink" href="https://home.dealsaving.com/view/50332">穿上超有味道的Free People新款清仓！低至$29.95!   </a></li>, <li><a href="/news/2020/08/27/9806492.html">王毅急访欧洲5国 发了4个信号 咋回事？</a></li>, <li><a href="/news/2020/08/27/9806434.html">反对脱钩或对中国更强硬? 拜登对华的真实政策</a></li>, <li><a href="/news/2020/08/27/9806431.html">“黄金护照”事件 “没人想拿家庭未来陪习近平一起疯”</a></li>, <li><a href="/news/2020/08/27/9806400.html">意大利米兰：华人这个姓氏 竟成当地第一大姓</a></li>, <li><a class="adslink" href="https://home.dealsaving.com/view/50345">穿出好衣品,Tahari ASL女装75% off低至$17!   </a></li>, <li><a href="/news/2020/08/27/9806373.html">美国其实暗助习近平？专家:因他能“一手搞垮共产党”</a></li>, <li><a href="/news/2020/08/27/9806336.html">微信被封申诉无门 深圳男子在腾讯大楼跳楼身亡</a></li>, <li><a href="/news/2020/08/27/9806325.html">百年最强飓风登陆美国 画面触目惊心</a></li>, <li><a href="/news/2020/08/27/9806309.html">赵立坚：蓬佩奥每开一次口 中国人民就更拥护共产党</a></li>, <li><a class="adslink" href="http://home.dealsaving.com/list/?cid=2&amp;ads=50320">名媛王妃都爱穿! DVF裹身裙真丝衫等低至3折！   </a></li>, <li><a href="/news/2020/08/27/9806293.html">为帮川普助选 白宫“金发妹”惊爆：家中8位女性患癌</a></li>, <li><a href="/news/2020/08/27/9806267.html">川普准儿媳“吼”上热搜 昔日当红女主播 比"后妈"还大1岁…</a></li>, <li><a href="/news/2020/08/27/9806207.html">“水果姐”生了！与“精灵王子”相爱多年 这狗粮太甜！</a></li>, <li><a href="/news/2020/08/27/9806185.html">豪言“宁坐宝马哭”被网暴10年“拜金女” 如今怎样了？</a></li>, <li><a class="adslink" href="https://home.dealsaving.com/view/50319">犹如第二层皮肤，高质量舒适无痕内裤5件$30! </a></li>, <li><a href="/news/2020/08/27/9806176.html">希拉里警告：大选当天 美国很可能会没有新总统诞生</a></li>, <li><a href="/news/2020/08/27/9806171.html">今天开新闻发布会，安倍可能要辞职…</a></li>, <li><a href="/news/2020/08/27/9806156.html">胡德堡基地连环命案 疑似失踪生化核武专家遗体发现</a></li>, <li><a href="/news/2020/08/27/9806146.html">特朗普:拜登辩论能力"突然提高" 是因为他"嗑药"了</a></li>, <li><a class="adslink" href="http://home.dealsaving.com/list/?cid=2&amp;ads=50338">顶级羊毛衬里休闲裤, 4种颜色   </a></li>, <li><a href="/news/2020/08/27/9806137.html">虎妈蔡美儿丈夫惊爆涉性骚扰 遭耶鲁停职调查</a></li>, <li><a href="/news/2020/08/27/9806122.html">批评“平权”华裔教授因言获罪，为平等而弃平等</a></li>, <li><a href="/news/2020/08/27/9806051.html">伊万卡穿青花瓷长裙太壮实 踩恨天高快撑不住</a></li>, <li><a href="/news/2020/08/27/9806043.html">从央视名主持人到阶下囚 沈冰出狱后尽显沧桑</a></li>, <li><a class="adslink" href="http://home.dealsaving.com/list/?cid=4&amp;ads=50344">Zojirushi 多功能智能电饭煲，适合小家庭   </a></li>, <li><a href="/news/2020/08/27/9806026.html">中国向南海发射4枚“航母杀手”导弹 美国：军队已待命</a></li>, <li><a href="/news/2020/08/27/9806004.html">黑人遭枪击怒火延烧！MLB MLS NBA大规模罢赛</a></li>, <li><a href="/news/2020/08/27/9806000.html">郭文贵爆料：拜登若胜选 拟推翻一中政策 承认台湾</a></li>, <li><a class="adslink" href="https://home.dealsaving.com/creditcard/">消费满$1000可得$250开卡奖励，买菜神卡</a></li>, <li class="first"><a href="//bbs.wenxuecity.com/catalog">《全部论坛》</a></li>, <li><a href="//bbs.wenxuecity.com/cooking/">私房小菜</a></li>, <li><a href="//bbs.wenxuecity.com/myhouse/">我爱我家</a></li>, <li><a href="//bbs.wenxuecity.com/travel/">世界风情</a></li>, <li><a href="//bbs.wenxuecity.com/style/">流行时尚</a></li>, <li><a href="//bbs.wenxuecity.com/znjy/">子女教育</a></li>, <li><a href="//bbs.wenxuecity.com/finance/">大千股坛</a></li>, <li><a href="//bbs.wenxuecity.com/tzlc/">投资理财</a></li>, <li><a href="//bbs.wenxuecity.com/kghy/">跨国婚姻</a></li>, <li><a class="adslink" href="http://home.dealsaving.com/list/?cid=2&amp;ads=50339">准备时不再混乱! ORGANIC大内置槽竹砧板!   </a></li>, <li><a h ...
# <a href="//www.haiwai.com/c-hw_tag_114/">[教育讲座]</a>
# <a href="//www.haiwai.com/c-hw_tag_114/1731200ci.html">9月FLEX总裁和资深顾问大学申请系列讲座</a>
# </li>, <li>
# <a href="//www.haiwai.com/c-hw_tag_114/">[教育讲座]</a>
# <a href="//www.haiwai.com/c-hw_tag_114/1731068ci.html">FLEX"通往大学之路(Pathway) ”分科目辅导项目</a>
# </li>, <li>
# <a href="//www.haiwai.com/c-hw_tag_114/">[教育讲座]</a>
# <a href="//www.haiwai.com/c-hw_tag_114/1729917ci.html">宜真美術學院8/15網上開放參觀免費試課</a>
# </li>, <li>
# <a href="//www.haiwai.com/c-hw_tag_114/">[教育讲座]</a>
# <a href="//www.haiwai.com/c-hw_tag_114/1728918ci.html">最新州长公告对加州4-12年级学生的影响</a>
# </li>, <li>
# <a href="//www.haiwai.com/c-hw_tag_114/">[教育讲座]</a>
# <a href="//www.haiwai.com/c-hw_tag_114/1721693ci.html">高薪转行数据分析师，若不成功分文不取</a>
# </li>, <li>
# <a href="//www.haiwai.com/c-hw_tag_114/">[教育讲座]</a>
# <a href="//www.haiwai.com/c-hw_tag_114/1707205ci.html">硅谷立捷房地产地产经纪辅导班</a>
# </li>, <li><a href="//www.haiwai.com/c-hw_tag_617/1731291ci.html">IKEA 垃圾桶</a></li>, <li><a href="//www.haiwai.com/c-hw_tag_283/1731290ci.html">搬家大甩卖</a></li>, <li><a href="//www.haiwai.com/c-hw_tag_534/1731270ci.html">Brea 高级社区吉屋出售好学区近购物中心</a></li>, <li><a href="//www.haiwai.com/c-hw_tag_111/1730396ci.html">诚征女友</a></li>, <li><a href="//www.haiwai.com/c-hw_tag_534/1730384ci.html">看房直播：海景豪宅开发机会</a></li>, <li><a href="//www.haiwai.com/c-hw_tag_534/1730308ci.html">崭新上市：威尼斯海滩，寸土寸金 建筑批文 189万美金</a></li>, <li><a href="//www.haiwai.com/c-hw_tag_534/1730307ci.html">风生水起Highland Park 投资房</a></li>, <li><a href="//www.haiwai.com/c-hw_tag_534/1730306ci.html">San Marina 高档学区房，工艺品中的精品</a></li>, <li><a href="//www.haiwai.com/c-hw_tag_534/1730305ci.html">女王项链无敌海景+全新设计批文</a></li>, <li><a href="//www.haiwai.com/c-hw_tag_534/1730304ci.html">Palos Verdes 半岛，学区观景房</a></li>, <li><a href="//www.haiwai.com/c-hw_tag_68/1730044ci.html">尔湾主卧分租，独立卫浴</a></li>, <li><a href="//www.haiwai.com/c-hw_tag_534/1730011ci.html">崭新上市：威尼斯海滩，寸土寸金 建筑批文 189万美金</a></li>, <li><a href="//www.haiwai.com/c-hw_tag_534/1730010ci.html">风生水起Highland Park 投资房</a></li>, <li><a href="//www.haiwai.com/c-hw_tag_534/1730009ci.html">San Marina 高档学区房，工艺品中的精品</a></li>, <li>
# <a href="//www.haiwai.com/store/list/?cid=1692">[餐饮美食]</a>
# <a href="//www.haiwai.com/store/1729362/">美国网络订餐科技 Online Food Ordering</a>
# </li>, <li>
# <a href="//www.haiwai.com/store/list/?cid=1695">[商业服务]</a>
# <a href="//www.haiwai.com/store/1728934/">可靠科技KeKaoKeJi</a>
# </li>, <li>
# <a href="//www.haiwai.com/store/list/?cid=1691">[教育/培训]</a>
# <a href="//www.haiwai.com/store/1728040/">DrJoeWriting</a>
# </li>, <li>
# <a href="//www.haiwai.com/store/list/?cid=1700">[医疗保健]</a>
# <a href="//www.haiwai.com/store/1714860/">华键美国</a>
# </li>, <li>
# <a href="//www.haiwai.com/store/list/?cid=1695">[商业服务]</a>
# <a href="//www.haiwai.com/store/1708913/">专业YouTube视频内容制作服务</a>
# </li>, <li>
# <a href="//www.haiwai.com/store/list/?cid=1699">[旅游/休闲/购物]</a>
# <a href="//www.haiwai.com/store/1708805/">云间牌馆</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/15078/35868.html">短篇小说【孟婆汤】</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=494134">石头弟弟</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/6323/35975.html">我们看错了近400年</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=375662">布兰雅</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/65237/35922.html">寻幽访胜到宾州</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=823307">yuntai</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/75758/35915.html">西班牙日记 - 疫情爆发前的日子（上）</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=994712">流浪的亮亮...</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/75626/35901.html">我们家——文革来了</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=949483">铿锵猪</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/35194/35799.html">数学家的故事</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=610983">朝霞满天</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/53242/35771.html">国男你是细腻还是矫情？</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=758514">BeijingGir...</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/77016/35731.html">反思3: 寻找我猝死发生的原因（II)</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=1060062">Jeff_503</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/25182/35571.html">日子越来越不好过到如此的地步</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=533773">菲儿天地</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/68017/35546.html">背包徒步－North Cascades National Park</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=930442">也猫</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/62877/35528.html">闲聊国家科学技术进步奖</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=805047">老生常谈12...</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/77130/35510.html">1989年的天安门广场： 枪口下的投票</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=1061371">平等性</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/1479/35455.html">你们这些地方口音可真害死我了！</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=325203">mychina</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/70796/35367.html">读左拉的代表作《萌芽》</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=967073">暖冬cool夏...</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/48069/35336.html">女人修车有优势！（慎入）</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=694572">x潇潇</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/71444/35256.html">英国史 被当众鞭打的王后</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=962253">longueuil</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/75433/35226.html">美国菜农 – 辣椒</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=1037513">谦谦美君子...</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/74857/34521.html">百搭的茄子</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=1031048">语蝶</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/47429/35127.html">日子怎么才能越过越松快</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=637898">南山碧竹</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/58768/35090.html">疫情下走进法国古老的小镇散散心</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=796249">尼斯</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/41038/35060.html">看电影《倾国之恋》</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=659595">晓青</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/70758/34955.html">一周一个马拉松 （Week 10) --- 目标达成</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=966556">polebear</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/46175/35018.html">混在美国国难回</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=701301">caizane</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/1926/35015.html">为什么看环法自行车赛</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=309558">落花飘零</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/14367/34977.html">帝王将相宁有种乎系列专题之一袁隆平</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=333576">菊香书屋</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/11378/34939.html">美国档案--吴宓汤用彤俞大维入境记录</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=296081">元亨利</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/37303/34910.html">都柏林：学院古书与公园大街</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=628218">广陵晓阳</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/70695/34832.html">台北101</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=965783">一切美好源...</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/73969/34841.html">12年了,被卷入假唱风波的2个女孩今何在？</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=1016423">xiaxi</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/64608/34810.html">这真的是在给美籍华人维权吗？</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=890111">牛城地主</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/69857/34782.html">COSTCO出售的牛肉的不同部位</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=932306">阳光下的遐...</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/60786/34777.html">曾经与今天的你，都如此美丽！</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=841029">多伦多橄榄...</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/7072/34755.html">【亮妈厨房】2020-41 简单好做的青椒葱饼</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=194497">亮亮妈妈</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/75999/34767.html">西弗吉尼亚*Babcock 州立公园</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=1045443">枣泥</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/77510/34766.html">你们那么土 就不难堪吗？？</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=1065530">木姜子_枫华...</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/45177/34703.html">与李泽厚的对话</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=692837">思想的远行...</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/67939/34641.html">文字可以如斯美丽</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=320184">just_4_fun</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/58515/34593.html">川普和拜登哪个当选对中国更好</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=808828">小思维</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/63040/34590.html">寂静之声：新闻述评系列（296）8/27/2020</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=836760">soundofsil...</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/75548/34580.html">好个不一样的人生</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=847437">moonsun</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/27715/34567.html">新泽西北部山区的度假村</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=552270">看风景</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/72462/34531.html">大火中烧毁的“Big Basin Redwoods State Park”</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=995572">拿铁咖啡</a>
# </li>, <li>
# <a class="blogc" href="/blog/202006/39616/26269.html">在静冈的海边小镇</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=648909">东京闲人</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/33170/34446.html">幸福就是善待你所爱的人</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=556165">美丽的人生...</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/73296/34417.html">追寻“音乐之声”</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=1008388">八卦评委</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/76415/34336.html">准备去露营</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=1051208">嵩山南路</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/77363/34304.html">我从大山走出来</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=1064504">科大瞬间</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/48366/34168.html">骨子里的福养 -- 在博物館里富養孩子</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=578808">yanlan</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/48977/34087.html">英國靈魂、流行歌曲天后首發獲*葛萊美最佳新人獎專輯</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=722465">肯老的</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/40063/34023.html">越南电影《夏天的滋味》 - 眷美的诗意</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=652465">绿叶红花美...</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/57575/34016.html">周末爬坡被美国人教育到了</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=799418">spot321</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/77295/34005.html">百年家国往事·民国篇</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=1063690">红茶遇上卡...</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/75495/33687.html">2020 游王府</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=1038829">云霞姐姐</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/73631/33944.html">北帕德里岛国家海滩徒步奇遇记 —— 第一天</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=1012370">魏玲</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/67103/33861.html">希望飞越【病毒长城】-兼送网友两幅画</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=916148">梦无紫薇</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/72006/33763.html">人生第一次重装徒步背包露营 </a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=989607">步入佳途</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/76036/33736.html">花样买房之seller financing (卖家贷款）</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=1046086">攀攀妈的房...</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/64833/33682.html">硅谷传奇——美国传奇：半导体工业之父罗伯特·诺伊斯</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=894147">L-Q</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/66653/33609.html">美国怎能不恨中国</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=903772">笨狼</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/59069/32689.html">教三小子换轮胎</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=789221">我冇醉</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/76035/33024.html">吳晗失之在算</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=1046197">boyi0127</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/63208/33105.html">笨鹅闯王府</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=874414">心雨烟尘</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/61002/32849.html">麦律师夫妇在美国共和党大会的演讲视频</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=844707">雅美之途</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/74234/33462.html">隐私  终随乱红飞花去</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=1021384">铃兰听风</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/19591/33453.html">总结一下我家孩子和我的心路历程</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=470551">2ndtimemom</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/77395/33452.html">感谢默默付出的人们</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=1064936">奋斗小米粒...</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/75393/33451.html">张一鸣和他的TikTok (II) 火箭般的3年</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=1037331">国华P</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/77271/33447.html">要信任就百分之一百二十地信任</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=1063289">野性de思维...</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/77249/33371.html">巡演故事</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=1063016">音来小提琴...</a>
# </li>, <li>
# <a class="blogc" href="/blog/202008/70246/33369.html">失控的中国是对美国最大的威胁</a>
# <a class="buname" href="/blog/goto.php?type=userid&amp;u=960347">朱头山</a>
# </li>, <li><a href="//www.wenxuecity.com/aboutus/wenxuecity.shtml" target="_blank">文学城简介</a></li>, <li><a href="//ads.wenxuecity.com/" target="_blank">广告服务</a></li>, <li><a href="//www.wenxuecity.com/aboutus/contact.shtml" target="_blank">联系我们</a></li>, <li><a href="//career.wenxuecity.com/" target="_blank">招聘信息</a></li>, <li><a href="//passport.wenxuecity.com/register.php" target="_blank">注册笔名</a></li>, <li><a href="/bbs/index.php?act=moderator" target="_blank">申请版主</a></li>, <li class="last"><a href="#" onclick="return favorite(window.location,document.title);" target="_blank">收藏文学城</a></li>]

# %%
headlines = []
for result in results:
    headline_url = result.find('a').attrs['href']
    headline = result.find('a').contents[0]
    headline = headline.replace("\r\n", "").strip()
    headlines.append((headline, headline_url))

# %%
headlines
# Out:
# [('首页', '//www.wenxuecity.com/'),
#  ('新闻', '//www.wenxuecity.com/news/'),
#  ('读图',
#   '//www.wenxuecity.com/news/photo/?utm_source=wxc&utm_medium=navi&utm_campaign=05242016'),
#  ('财经', '//bbs.wenxuecity.com/financenews/'),
#  ('教育', '//www.wenxuecity.com/edu/'),
#  ('家居', '//www.wenxuecity.com/home/'),
#  ('健康', '//www.wenxuecity.com/health/'),
#  ('美食', '//www.wenxuecity.com/cooking/'),
#  ('时尚', '//www.wenxuecity.com/style/'),
#  ('旅游', '//www.wenxuecity.com/travel/'),
#  ('影视', '//www.wenxuecity.com/video/'),
#  ('博客', '//blog.wenxuecity.com/'),
#  ('群组', '//groups.wenxuecity.com/'),
#  ('悠游', '/yoyo/?act=list'),
#  ('论坛', '//bbs.wenxuecity.com/'),
#  ('他当面告诉王毅：中国的胁迫外交对加拿大无效', '/news/2020/08/27/9808438.html'),
#  ('便宜！Ann Taylor全网高达5折, 打折区额外70% off!', 'https://home.dealsaving.com/'),
#  ('赶快申请蓝钻卡，开户送$750，旅游餐饮返2%!',
#   'https://www.cardbenefit.com/search-credit-cards/?cardChoice=creditRating&ccRating=good-credit&introid=sapphire&show=42&src=wxc1'),
#  ('“香港人”若获诺贝尔和平奖？ 王毅：勿干涉中国内政', '/news/2020/08/27/9808435.html'),
#  ('美国国防部指责中国军队在南海发射导弹“破坏地区稳定”', '/news/2020/08/27/9808433.html'),
#  ('罕见！La Mer豪送$452好礼，包含正装神奇面霜', 'https://www.dealmoon.com/wxc1'),
#  ('浙企高管被警方跨省询问至凌晨 两天后突然猝死', '/news/2020/08/27/9808431.html'),
#  ('中石油巨亏300亿，这家A股更离谱，半年巨亏270亿', '/news/2020/08/27/9808427.html'),
#  ('台湾网红“馆长”陈之汉深夜被人当街连开 3 枪', '/news/2020/08/27/9808321.html'),
#  ('施华洛世奇最受欢迎的天鹅项链和耳环5折！低至$39!', 'https://home.dealsaving.com/view/50330'),
#  ('小鹏汽车登陆纽交所：市值已破百亿美元', '/news/2020/08/27/9808316.html'),
#  ('临危受命，TikTok 的新负责人是谁？', '/news/2020/08/27/9808310.html'),
#  ('成人展惊现“房思琪”情趣桌游，“吃相”太难看', '/news/2020/08/27/9808298.html'),
#  ('17岁“川普粉”枪杀抗议者 美国已如此分裂？', '/news/2020/08/27/9807904.html'),
#  ('舒适又有气质! Express清仓区额外60% off低至$6!',
#   'https://home.dealsaving.com/view/50349'),
#  ('北京上空惊现“手指”云 网友：这是“神仙指路”吗？', '/news/2020/08/27/9807699.html'),
#  ('慈禧年轻美照刷屏 小伙手绘画竟引故宫考证 老专家都上当', '/news/2020/08/27/9807694.html'),
#  ('“虎妈”老公陷性骚扰丑闻：身为耶鲁知名教授的他做过什么', '/news/2020/08/27/9807687.html'),
#  ('共和党大会上宣誓入籍女子：没想到特朗普会参加', '/news/2020/08/27/9807670.html'),
#  ('周生生金饰5折起！珍珠贝母、镂空雪花项链超美～', 'https://www.dealmoon.com/wxc2'),
#  ('台湾反共网红“馆长”突遭枪击 中多枪倒卧血泊', '/news/2020/08/27/9807649.html'),
#  ('王岐山隐身太久？曝其父为国民党军官 文章被翻炒', '/news/2020/08/27/9807639.html'),
#  ('彭斯提名演讲 轰拜登“中共啦啦队长”(视频)', '/news/2020/08/27/9807610.html'),
#  ('儿子惨遭枪击 黑人妈妈说话了 煽风点火的CNN傻眼了', '/news/2020/08/27/9807565.html'),
#  ('飓风“全怪兽模式”直扑美国 恐引致命暴潮150万人须撤离', '/news/2020/08/27/9807560.html'),
#  ('消除胸闷气短/头晕耳鸣, 就选美国 [心血通/益脑灵]',
#   'http://bbs.wenxuecity.com/advpost/3071.html'),
#  ('习近平失两张王牌 李克强再遭重击', '/news/2020/08/27/9807545.html'),
#  ('美国社会的火药库：疫情、种族问题和武装民兵…', '/news/2020/08/27/9807523.html'),
#  ('拆除7.1亿的豪华中学：一次作妖、二次曝光、三杯自罚', '/news/2020/08/27/9807507.html'),
#  ('盲女杀人事件：被初恋挖眼后 拿斧头砍向丈夫', '/news/2020/08/27/9807502.html'),
#  ('LOFT又开仓！泡泡袖开衫$8, 西服$20，这波别错过', 'https://www.dealmoon.com/wxc3'),
#  ('让NBA罢赛 奥巴马声援的黑人是谁？劣迹斑斑曾强奸', '/news/2020/08/27/9807319.html'),
#  ('沃尔玛证实 将与微软联手收购TikTok', '/news/2020/08/27/9807297.html'),
#  ('猛男影帝人设崩塌：曾给周润发写情书 婚后和男星同床', '/news/2020/08/27/9807295.html'),
#  ('川普共和党大会今晚演讲稿提前披露！火力全开！', '/news/2020/08/27/9807250.html'),
#  ('高中生居家必备 SAT/ACT/AP 线上刷题+解答',
#   'https://bbs.wenxuecity.com/bbs/advpost/2772.html'),
#  ('实在扛不住了！美国第一间百货公司“吹熄灯号”', '/news/2020/08/27/9807229.html'),
#  ('陆媒评论人：小心美军！川普或正酝酿“危险动作”', '/news/2020/08/27/9807228.html'),
#  ('疫情下美国人开始存钱！储蓄率创33%历史新高！', 'http://cn.dealam.com/?ref=wxrst4406346674'),
#  ('涉嫌侮辱前中共领导人 知名女星为何敢这样做', '/news/2020/08/27/9807200.html'),
#  ('传TikTok与微软可能在48小时内达交易 交易规模达…', '/news/2020/08/27/9807165.html'),
#  ('SpaceX成功跳跃！火星旅行不再是梦，科技正在改变生活',
#   'http://pubads.g.doubleclick.net/gampad/clk?id=112296481&iu=/30613721/homepage_news'),
#  ('当年的异见艺术家华涌：逃亡至国外仍被“穷追猛打”', '/news/2020/08/27/9807157.html'),
#  ('盲人维权律师陈光诚：中共是人类公敌(视频/中文字幕)', '/news/2020/08/27/9807138.html'),
#  ('威州骚乱：17岁白男射杀2示威者 持枪淡定走向警察', '/news/2020/08/27/9806556.html'),
#  ('中南海开座谈会，习近平究竟要如何转危为机？', '/news/2020/08/27/9806510.html'),
#  ('穿上超有味道的Free People新款清仓！低至$29.95!',
#   'https://home.dealsaving.com/view/50332'),
#  ('王毅急访欧洲5国 发了4个信号 咋回事？', '/news/2020/08/27/9806492.html'),
#  ('反对脱钩或对中国更强硬? 拜登对华的真实政策', '/news/2020/08/27/9806434.html'),
#  ('“黄金护照”事件 “没人想拿家庭未来陪习近平一起疯”', '/news/2020/08/27/9806431.html'),
#  ('意大利米兰：华人这个姓氏 竟成当地第一大姓', '/news/2020/08/27/9806400.html'),
#  ('穿出好衣品,Tahari ASL女装75% off低至$17!', 'https://home.dealsaving.com/view/50345'),
#  ('美国其实暗助习近平？专家:因他能“一手搞垮共产党”', '/news/2020/08/27/9806373.html'),
#  ('微信被封申诉无门 深圳男子在腾讯大楼跳楼身亡', '/news/2020/08/27/9806336.html'),
#  ('百年最强飓风登陆美国 画面触目惊心', '/news/2020/08/27/9806325.html'),
#  ('赵立坚：蓬佩奥每开一次口 中国人民就更拥护共产党', '/news/2020/08/27/9806309.html'),
#  ('名媛王妃都爱穿! DVF裹身裙真丝衫等低至3折！',
#   'http://home.dealsaving.com/list/?cid=2&ads=50320'),
#  ('为帮川普助选 白宫“金发妹”惊爆：家中8位女性患癌', '/news/2020/08/27/9806293.html'),
#  ('川普准儿媳“吼”上热搜 昔日当红女主播 比"后妈"还大1岁…', '/news/2020/08/27/9806267.html'),
#  ('“水果姐”生了！与“精灵王子”相爱多年 这狗粮太甜！', '/news/2020/08/27/9806207.html'),
#  ('豪言“宁坐宝马哭”被网暴10年“拜金女” 如今怎样了？', '/news/2020/08/27/9806185.html'),
#  ('犹如第二层皮肤，高质量舒适无痕内裤5件$30!', 'https://home.dealsaving.com/view/50319'),
#  ('希拉里警告：大选当天 美国很可能会没有新总统诞生', '/news/2020/08/27/9806176.html'),
#  ('今天开新闻发布会，安倍可能要辞职…', '/news/2020/08/27/9806171.html'),
#  ('胡德堡基地连环命案 疑似失踪生化核武专家遗体发现', '/news/2020/08/27/9806156.html'),
#  ('特朗普:拜登辩论能力"突然提高" 是因为他"嗑药"了', '/news/2020/08/27/9806146.html'),
#  ('顶级羊毛衬里休闲裤, 4种颜色', 'http://home.dealsaving.com/list/?cid=2&ads=50338'),
#  ('虎妈蔡美儿丈夫惊爆涉性骚扰 遭耶鲁停职调查', '/news/2020/08/27/9806137.html'),
#  ('批评“平权”华裔教授因言获罪，为平等而弃平等', '/news/2020/08/27/9806122.html'),
#  ('伊万卡穿青花瓷长裙太壮实 踩恨天高快撑不住', '/news/2020/08/27/9806051.html'),
#  ('从央视名主持人到阶下囚 沈冰出狱后尽显沧桑', '/news/2020/08/27/9806043.html'),
#  ('Zojirushi 多功能智能电饭煲，适合小家庭',
#   'http://home.dealsaving.com/list/?cid=4&ads=50344'),
#  ('中国向南海发射4枚“航母杀手”导弹 美国：军队已待命', '/news/2020/08/27/9806026.html'),
#  ('黑人遭枪击怒火延烧！MLB MLS NBA大规模罢赛', '/news/2020/08/27/9806004.html'),
#  ('郭文贵爆料：拜登若胜选 拟推翻一中政策 承认台湾', '/news/2020/08/27/9806000.html'),
#  ('消费满$1000可得$250开卡奖励，买菜神卡', 'https://home.dealsaving.com/creditcard/'),
#  ('《全部论坛》', '//bbs.wenxuecity.com/catalog'),
#  ('私房小菜', '//bbs.wenxuecity.com/cooking/'),
#  ('我爱我家', '//bbs.wenxuecity.com/myhouse/'),
#  ('世界风情', '//bbs.wenxuecity.com/travel/'),
#  ('流行时尚', '//bbs.wenxuecity.com/style/'),
#  ('子女教育', '//bbs.wenxuecity.com/znjy/'),
#  ('大千股坛', '//bbs.wenxuecity.com/finance/'),
#  ('投资理财', '//bbs.wenxuecity.com/tzlc/'),
#  ('跨国婚姻', '//bbs.wenxuecity.com/kghy/'),
#  ('准备时不再混乱! ORGANIC大内置槽竹砧板!',
#   'http://home.dealsaving.com/list/?cid=2&ads=50339'),
#  ('1989年的天安门广场（五）生与死的见证', '/bbs/memory/1383459.html'),
#  ('做地主可能遇到的问题   三，管理', '/bbs/tzlc/1415210.html'),
#  ('如何善用免税计划提升投资回报率, 实现0％税率退休? (视频)',
#   'https://bbs.wenxuecity.com/advpost/3143.html'),
#  ('拜登难圆总统梦', '/bbs/currentevent/2244631.html'),
#  ('有钱人花1.35亿 把房子装出了1350元的效果', '/news/2020/08/27/socialnews-196166.html'),
#  ('香港男子二次感染新冠之谜！抗体消失，疫苗无用？',
#   'http://pubads.g.doubleclick.net/gampad/clk?id=5082575461&iu=/30613721/homepage_hottopic'),
#  ('狂言：“美国有什么好啊？”', '/bbs/currentevent/2244559.html'),
#  ('裸体趴体百人确诊 参加者:我除了口罩,啥都没穿', '/news/2020/08/27/socialnews-196165.html'),
#  ('网红国民女友不雅视频疯传 形象崩毁', '/news/2020/08/27/socialnews-196163.html'),
#  ('慎入：人在轮下满地血 妻子倒车辗毙丈夫吓傻', '/news/2020/08/27/socialnews-196162.html'),
#  ('恐怖 女子被杀抛尸化粪池 前夫行凶后外游半个月', '/news/2020/08/27/socialnews-196161.html'),
#  ('萧婷：北京大院子弟的社会“潜规则”', '/bbs/memory/1383321.html'),
#  ('Woodlawn與您乘風破浪 攜手未來', 'http://am1400.wixsite.com/home/woodlawn3'),
#  ('被枪毙和陪枪毙.....', '/bbs/memory/1383329.html'),
#  ('另类大院的故事（续完）', '/bbs/memory/1383328.html'),
#  ('一集拿下9.3分，这部再创收视的顶级神剧，太过瘾了', '/news/2020/08/27/ent-195248.html'),
#  ('朱莉把大女儿当男孩子养，14岁从没穿过女装', '/news/2020/08/27/ent-195252.html'),
#  ('马伊琍自曝被女儿催恋爱，择偶条件都很细致', '/news/2020/08/27/ent-195247.html'),
#  ('李亚男挺孕肚出街，老公王祖蓝跟随却被误认成保姆', '/news/2020/08/27/ent-195246.html'),
#  ('杨幂和魏大勋掐点暗秀恩爱，女儿小糯米近况曝光', '/news/2020/08/27/ent-195245.html'),
#  ('新版“黄雀行动”告终 12名逃亡香港抗争者“送中”', '/bbs/rdzn/4506844.html'),
#  ('查理曼大帝的后宫', '/bbs/memory/1383207.html'),
#  ('谈文明史不谈人类史，都是以偏概全', '/bbs/memory/1383244.html'),
#  ('1916年9月在旧金山入境的清华学校选送留美的10名专科女生（上）', '/bbs/memory/1383311.html'),
#  ('再返“6”时代，三大因素助人民币汇率“弹回”高点', '/bbs/financenews/13226.html'),
#  ('2万亿美元苹果背后的A股公司：业绩上半年暴增10倍', '/bbs/financenews/13220.html'),
#  ('揭秘10个富豪的家庭出身，80%来自这种家庭……', '/bbs/financenews/13223.html'),
#  ('中国“鞋王”倒下，林青霞老公套现210亿逃离？', '/bbs/financenews/13222.html'),
#  ('美国总统冷知识16则，你知道几个？', '/news/2020/08/26/socialnews-196144.html'),
#  ('经过4次手术，“折叠女孩”终于可以抬头看到天了！', '/news/2020/08/26/socialnews-196145.html'),
#  ('逃不掉！她一接到捧花男友"狂奔"，1年后还是结婚了', '/news/2020/08/26/socialnews-196146.html'),
#  ('时尚又实用！多功能小挎包，5色可选好评如潮！',
#   'http://home.dealsaving.com/list/?cid=2&ads=50341'),
#  ('两性关系的衡量， 什么样的感情才是好', '/bbs/kghy/3346912.html'),
#  ('今秋韩系穿搭，美到惊艳！', '/bbs/style/2286335.html'),
#  ('YI 1080p室内安防摄像头,防盗/看家/看店/看娃',
#   'http://home.dealsaving.com/list/?cid=4&ads=50347'),
#  ('狂想后疫时代 （1）', '/bbs/na/1982459.html'),
#  ('看电视连续剧《爱之初》', '/bbs/tv/1338292.html'),
#  ('Gibson Home 彩色陶瓷餐具12件套', 'https://home.dealsaving.com/view/50346'),
#  ('因为结局、遗憾弃剧 - 《女世子》', '/bbs/tv/1338318.html'),
#  ('慢慢长路，过关三年半大检查！', '/bbs/health/924746.html'),
#  ('夏天多喝汤', '/bbs/health/924761.html'),
#  ('会捉谜藏的癌细胞', '/bbs/health/924765.html'),
#  ('《你在我心里》', '/bbs/ktv/2000568.html'),
#  ('【庆祝七夕】Trouble Sleeping by 玫瑰花', '/bbs/ktv/1999753.html'),
#  ('写给看得懂的你（养生心得）', '/bbs/health/924779.html'),
#  ('初秋日系穿搭超气质！简约显高杂志风', '/bbs/style/2286336.html'),
#  ('看看女神怎样穿衬衣！', '/bbs/style/2286314.html'),
#  ('巴黎的橱窗风格', '/bbs/style/2286318.html'),
#  ('吃货的心结', '/bbs/cooking/1673386.html'),
#  ('中学阶段父母的责任', '/bbs/znjy/5036451.html'),
#  ('美丽的地方却有个魔鬼的名字', '/bbs/travel/634255.html'),
#  ('今早起来看了一阵国内新闻。。。', '/bbs/myhouse/9734059.html'),
#  ('2019年6月都柏林（3）：学院古书与绿地公园大街', '/bbs/travel-german/634246.html'),
#  ('欧洲的祖宗：希腊(4)－文明的味道', '/bbs/travel/634184.html'),
#  ('我的抗抑郁法之三---顺其自然与疫共存', '/bbs/travel/634227.html'),
#  ('旅途上的家----- 说不尽的Airbnb', '/bbs/travel/634241.html'),
#  ('我的啃小计划', '/bbs/znjy/5036352.html'),
#  ('自制麦当劳人气早餐Breakfast Burrito - 专业厨师带你自家开厨 [图文+视频]',
#   '/bbs/breakfast/1673240.html'),
#  ('檸檬方 (Lemon Bars) 早上配咖啡，午后配下午茶，美极了！（图文+视频）', '/bbs/cooking/1673283.html'),
#  ('家庭版新疆烤包子：不求正宗，但求能符合家人的口味，好吃看得见（图文，视频）', '/bbs/cooking/1673325.html'),
#  ('香蕉松饼，最传统的配方，完美还原早餐店Brunch的味道！【视频+图文】', '/bbs/breakfast/1673227.html'),
#  ('茄子太多换个吃法 网红擂椒茄子真是太好吃了【图文+视频】', '/bbs/6460353112/1673163.html'),
#  ('肉松面包卷，咸香松软卷不裂（图片+文字+视频）', '/bbs/bread/1673165.html'),
#  ('素食也可以这么好吃！这几道素食下饭菜，色香味俱全', '//www.haiwai.com/article/1731461/'),
#  ('三伏天，牛奶别再直接喝了，试试此做法，香甜Q弹，孩子百吃不厌', '//www.haiwai.com/article/1731459/'),
#  ('晚餐整一道家常版剁椒蒸鱼头，用土豆粉打底，肉质细嫩，香气十足', '//www.haiwai.com/article/1731457/'),
#  ('孩子爱吃炸鸡柳 自己在家做更好更健康', '//www.haiwai.com/article/1731455/'),
#  ('虫草花鸡汤，既好看又好喝，出锅孩子抢着喝光', '//www.haiwai.com/article/1731453/'),
#  ('别再出去吃麻辣烫了，教你在家做，几步就上桌，又香又辣，超下饭', '//www.haiwai.com/article/1731451/'),
#  ('家常菜这样做，简单又好吃，你学会了吗？', '//www.haiwai.com/article/1731449/'),
#  ('丝瓜丸子汤我家一周煮2次，简单营养，清淡鲜香，一家人都爱吃', '//www.haiwai.com/article/1731447/'),
#  ('今天早餐吃什么？这份肉沫早餐面推荐给你', '//www.haiwai.com/article/1731445/'),
#  ('凉粉在你家乡是个什么吃法？', '//www.haiwai.com/article/1731442/'),
#  ('1盆发面1把葱花，做个葱花油饼吃，简单五步就搞定，葱香味十足！', '//www.haiwai.com/article/1731413/'),
#  ('家庭简易版赛螃蟹，五分钟即可完成这道菜，口感滑嫩味道鲜美', '//www.haiwai.com/article/1731411/'),
#  ('别再把金针菇放火锅吃了，换种新吃法，好吃又好看，还超简单', '//www.haiwai.com/article/1731409/'),
#  ('菜梗太硬不要扔，加入咸菜这样做，就是一道夏日爽口下酒菜', '//www.haiwai.com/article/1731407/'),
#  ('[教育讲座]', '//www.haiwai.com/c-hw_tag_114/'),
#  ('[教育讲座]', '//www.haiwai.com/c-hw_tag_114/'),
#  ('[教育讲座]', '//www.haiwai.com/c-hw_tag_114/'),
#  ('[教育讲座]', '//www.haiwai.com/c-hw_tag_114/'),
#  ('[教育讲座]', '//www.haiwai.com/c-hw_tag_114/'),
#  ('[教育讲座]', '//www.haiwai.com/c-hw_tag_114/'),
#  ('IKEA 垃圾桶', '//www.haiwai.com/c-hw_tag_617/1731291ci.html'),
#  ('搬家大甩卖', '//www.haiwai.com/c-hw_tag_283/1731290ci.html'),
#  ('Brea 高级社区吉屋出售好学区近购物中心', '//www.haiwai.com/c-hw_tag_534/1731270ci.html'),
#  ('诚征女友', '//www.haiwai.com/c-hw_tag_111/1730396ci.html'),
#  ('看房直播：海景豪宅开发机会', '//www.haiwai.com/c-hw_tag_534/1730384ci.html'),
#  ('崭新上市：威尼斯海滩，寸土寸金 建筑批文 189万美金',
#   '//www.haiwai.com/c-hw_tag_534/1730308ci.html'),
#  ('风生水起Highland Park 投资房', '//www.haiwai.com/c-hw_tag_534/1730307ci.html'),
#  ('San Marina 高档学区房，工艺品中的精品', '//www.haiwai.com/c-hw_tag_534/1730306ci.html'),
#  ('女王项链无敌海景+全新设计批文', '//www.haiwai.com/c-hw_tag_534/1730305ci.html'),
#  ('Palos Verdes 半岛，学区观景房', '//www.haiwai.com/c-hw_tag_534/1730304ci.html'),
#  ('尔湾主卧分租，独立卫浴', '//www.haiwai.com/c-hw_tag_68/1730044ci.html'),
#  ('崭新上市：威尼斯海滩，寸土寸金 建筑批文 189万美金',
#   '//www.haiwai.com/c-hw_tag_534/1730011ci.html'),
#  ('风生水起Highland Park 投资房', '//www.haiwai.com/c-hw_tag_534/1730010ci.html'),
#  ('San Marina 高档学区房，工艺品中的精品', '//www.haiwai.com/c-hw_tag_534/1730009ci.html'),
#  ('[餐饮美食]', '//www.haiwai.com/store/list/?cid=1692'),
#  ('[商业服务]', '//www.haiwai.com/store/list/?cid=1695'),
#  ('[教育/培训]', '//www.haiwai.com/store/list/?cid=1691'),
#  ('[医疗保健]', '//www.haiwai.com/store/list/?cid=1700'),
#  ('[商业服务]', '//www.haiwai.com/store/list/?cid=1695'),
#  ('[旅游/休闲/购物]', '//www.haiwai.com/store/list/?cid=1699'),
#  ('短篇小说【孟婆汤】', '/blog/202008/15078/35868.html'),
#  ('我们看错了近400年', '/blog/202008/6323/35975.html'),
#  ('寻幽访胜到宾州', '/blog/202008/65237/35922.html'),
#  ('西班牙日记 - 疫情爆发前的日子（上）', '/blog/202008/75758/35915.html'),
#  ('我们家——文革来了', '/blog/202008/75626/35901.html'),
#  ('数学家的故事', '/blog/202008/35194/35799.html'),
#  ('国男你是细腻还是矫情？', '/blog/202008/53242/35771.html'),
#  ('反思3: 寻找我猝死发生的原因（II)', '/blog/202008/77016/35731.html'),
#  ('日子越来越不好过到如此的地步', '/blog/202008/25182/35571.html'),
#  ('背包徒步－North Cascades National Park', '/blog/202008/68017/35546.html'),
#  ('闲聊国家科学技术进步奖', '/blog/202008/62877/35528.html'),
#  ('1989年的天安门广场： 枪口下的投票', '/blog/202008/77130/35510.html'),
#  ('你们这些地方口音可真害死我了！', '/blog/202008/1479/35455.html'),
#  ('读左拉的代表作《萌芽》', '/blog/202008/70796/35367.html'),
#  ('女人修车有优势！（慎入）', '/blog/202008/48069/35336.html'),
#  ('英国史 被当众鞭打的王后', '/blog/202008/71444/35256.html'),
#  ('美国菜农 – 辣椒', '/blog/202008/75433/35226.html'),
#  ('百搭的茄子', '/blog/202008/74857/34521.html'),
#  ('日子怎么才能越过越松快', '/blog/202008/47429/35127.html'),
#  ('疫情下走进法国古老的小镇散散心', '/blog/202008/58768/35090.html'),
#  ('看电影《倾国之恋》', '/blog/202008/41038/35060.html'),
#  ('一周一个马拉松 （Week 10) --- 目标达成', '/blog/202008/70758/34955.html'),
#  ('混在美国国难回', '/blog/202008/46175/35018.html'),
#  ('为什么看环法自行车赛', '/blog/202008/1926/35015.html'),
#  ('帝王将相宁有种乎系列专题之一袁隆平', '/blog/202008/14367/34977.html'),
#  ('美国档案--吴宓汤用彤俞大维入境记录', '/blog/202008/11378/34939.html'),
#  ('都柏林：学院古书与公园大街', '/blog/202008/37303/34910.html'),
#  ('台北101', '/blog/202008/70695/34832.html'),
#  ('12年了,被卷入假唱风波的2个女孩今何在？', '/blog/202008/73969/34841.html'),
#  ('这真的是在给美籍华人维权吗？', '/blog/202008/64608/34810.html'),
#  ('COSTCO出售的牛肉的不同部位', '/blog/202008/69857/34782.html'),
#  ('曾经与今天的你，都如此美丽！', '/blog/202008/60786/34777.html'),
#  ('【亮妈厨房】2020-41 简单好做的青椒葱饼', '/blog/202008/7072/34755.html'),
#  ('西弗吉尼亚*Babcock 州立公园', '/blog/202008/75999/34767.html'),
#  ('你们那么土 就不难堪吗？？', '/blog/202008/77510/34766.html'),
#  ('与李泽厚的对话', '/blog/202008/45177/34703.html'),
#  ('文字可以如斯美丽', '/blog/202008/67939/34641.html'),
#  ('川普和拜登哪个当选对中国更好', '/blog/202008/58515/34593.html'),
#  ('寂静之声：新闻述评系列（296）8/27/2020', '/blog/202008/63040/34590.html'),
#  ('好个不一样的人生', '/blog/202008/75548/34580.html'),
#  ('新泽西北部山区的度假村', '/blog/202008/27715/34567.html'),
#  ('大火中烧毁的“Big Basin Redwoods State Park”', '/blog/202008/72462/34531.html'),
#  ('在静冈的海边小镇', '/blog/202006/39616/26269.html'),
#  ('幸福就是善待你所爱的人', '/blog/202008/33170/34446.html'),
#  ('追寻“音乐之声”', '/blog/202008/73296/34417.html'),
#  ('准备去露营', '/blog/202008/76415/34336.html'),
#  ('我从大山走出来', '/blog/202008/77363/34304.html'),
#  ('骨子里的福养 -- 在博物館里富養孩子', '/blog/202008/48366/34168.html'),
#  ('英國靈魂、流行歌曲天后首發獲*葛萊美最佳新人獎專輯', '/blog/202008/48977/34087.html'),
#  ('越南电影《夏天的滋味》 - 眷美的诗意', '/blog/202008/40063/34023.html'),
#  ('周末爬坡被美国人教育到了', '/blog/202008/57575/34016.html'),
#  ('百年家国往事·民国篇', '/blog/202008/77295/34005.html'),
#  ('2020 游王府', '/blog/202008/75495/33687.html'),
#  ('北帕德里岛国家海滩徒步奇遇记 —— 第一天', '/blog/202008/73631/33944.html'),
#  ('希望飞越【病毒长城】-兼送网友两幅画', '/blog/202008/67103/33861.html'),
#  ('人生第一次重装徒步背包露营', '/blog/202008/72006/33763.html'),
#  ('花样买房之seller financing (卖家贷款）', '/blog/202008/76036/33736.html'),
#  ('硅谷传奇——美国传奇：半导体工业之父罗伯特·诺伊斯', '/blog/202008/64833/33682.html'),
#  ('美国怎能不恨中国', '/blog/202008/66653/33609.html'),
#  ('教三小子换轮胎', '/blog/202008/59069/32689.html'),
#  ('吳晗失之在算', '/blog/202008/76035/33024.html'),
#  ('笨鹅闯王府', '/blog/202008/63208/33105.html'),
#  ('麦律师夫妇在美国共和党大会的演讲视频', '/blog/202008/61002/32849.html'),
#  ('隐私  终随乱红飞花去', '/blog/202008/74234/33462.html'),
#  ('总结一下我家孩子和我的心路历程', '/blog/202008/19591/33453.html'),
#  ('感谢默默付出的人们', '/blog/202008/77395/33452.html'),
#  ('张一鸣和他的TikTok (II) 火箭般的3年', '/blog/202008/75393/33451.html'),
#  ('要信任就百分之一百二十地信任', '/blog/202008/77271/33447.html'),
#  ('巡演故事', '/blog/202008/77249/33371.html'),
#  ('失控的中国是对美国最大的威胁', '/blog/202008/70246/33369.html'),
#  ('文学城简介', '//www.wenxuecity.com/aboutus/wenxuecity.shtml'),
#  ('广告服务', '//ads.wenxuecity.com/'),
#  ('联系我们', '//www.wenxuecity.com/aboutus/contact.shtml'),
#  ('招聘信息', '//career.wenxuecity.com/'),
#  ('注册笔名', '//passport.wenxuecity.com/register.php'),
#  ('申请版主', '/bbs/index.php?act=moderator'),
#  ('收藏文学城', '#')]

# %%
def get_author(url):
    page_content = requests.get(url, verify=False).content # import without checking SSL
    soup = BeautifulSoup(page_content, 'html.parser') # parser that works with Chinese characters bs4
    author = soup.find('span', itemprop="author") # Grabs author
    return author

authors = [] # Tuples in format ("This is a headline", "/this/is/a/URL.html")
for headline in headlines:
    if headline[1].find('.com') == -1: # If not an ad/external link
        url = "https://www.wenxuecity.com/" + headline[1]  
        author = get_author(url)
        if author != None:
            authors.append(author.text)
# Out:
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# ...
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.wenxuecity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %% [markdown]
# # Appendix: Data Cleaning Guide and Functions
# ## Retrieving Data from a Data Source
#
# Most of the data you work with will be in JSON format. This kind of data is usually pretty easy to work with -- it's easy to read, nicely and neatly nested, and you've seen it everywhere. Here's a brief script that gives you a framework for extracting a JSON object as an API response.

# %%
def get_api_json(url, params={}):
    """Return the JSON object retrieved from a url with optional parameters"""
    try:
        obj = requests.get(url, params=params)
    except requests.exceptions.RequestException as e:
        return SystemExit(e)

    try:
        data = obj.json()
    except:
        data = json.loads(obj.text())
    
    return data

# %% [markdown]
# Sometimes the data you're looking for will be HTML data. This is true when we're dealing with a plain webscrape as opposed to an official or external-facing API. You shouldn't encounter these too often.

# %%
def get_api_html(url):
    """Return a BeautifulSoup object representing the HTML of a website"""
    try:
        obj = requests.get(url)
    except requests.exceptions.RequestException as e:
        return SystemExit(e)
    
    soup = BeautifulSoup(obj.content, 'html.parser')
    return soup

# %% [markdown]
# For `BeautifulSoup` you only really need to be concerned with one method -- the `find_all` function, which takes in a string or regular expressions and returns a list of all matches. For instance, `soup.find_all('h3')` returns a list of all `h3` tags in the HTML. Additionally, `soup.find_all(class_='desc_wrap_ck3')` returns a list of all items that match that `class`.

# %% [markdown]
# ## REGular EXpressions
#
# A lot of times you'll need regex to filter out API results and clean entries dynamically. Regex is supplied to python via the `re` package. A guide to regular expressions can be found at https://www.regular-expressions.info/tutorial.html (the Bible for regex). If you need help with a particular regex just message Kanyes :)
#
# There are two functions in particular that you should know how to use -- `re.sub(pattern, str or func, target)` will search for a pattern within a target string and replace it, either with a static string or with a function that can take in the pattern match as an argument.
#
# For example, `re.sub(r'\(.*\)|\{.*\}', "", "hello, (world)")` will strip out anything in parantheses or brackets from the target string.
#
# Likewise, `re.sub(r'([^0-9])', lambda rgx: f"{rgx.group(1)}", "hello 123 world")` will extract anything that isn't a number (`^[0-9]`) from the target string and substitute the extraction back into the target string, so `"hello 123 world"` becomes `"hello  world"`.

# %% [markdown]
# ## Filtering and Modifying an API response
#
# Sometimes, the data within an API response isn't good enough itself -- we might need to add a temporary field in real-time as we're processing an API result. For instance, in the Yummly 28k dataset, we didn't have a flag for diet. While we're examining data and checking if it's good enough for a card, we need a way to create this new diet field within the response temporarily. The following functions allow us to do some basic filtering and modifying of a response.
#
# This is most useful when the API returns a collection or list of objects rather than just 1 object -- for instance, a recipes endpoint which returns 100 recipes or a concerts endpoint that returns 20 concerts.

# %% [markdown]
# Adding a temp field is simple enough -- just do something like:
# ```
# for result in data['results']:
#     result['new_field'] = function_or_value()
# ```
#
# Removing a field is also easy; use
# ```
# del data['field_to_be_removed']
# ```

# %%
def extract_field_from_list(l, field_name):
    """Given a list of dicts, extract a field from each dict"""
    return [e[field_name] for e in l]

def filter_list(l, boolexpr):
    """Filter a list based on a boolean expression"""
    return [e for e in l if boolexpr(e)]

def clean_list(l, regexpr):
    """Given a regex lambda function, clean a particular field in a list of dicts"""
    return [regexpr(e) for e in l]

# Example usage: 
# extract_field_from_list(data['recipes'], 'title')
# filter_list(data['recipes'], lambda recipe: recipe['rating'] > 3)
# clean_list(data['recipes'], lambda recipe: re.sub(r'([A-Za-z])', lambda rgx: f"{rgx.group(1)}", recipe['title']))

# %% [markdown]
# ## Analytics and Information
# Here are some basic functions that allow you to see the distribution of a certain field in the data. This can be helpful in testing how diverse an API response is, or testing the quality of the response.

# %%
def hist(vals):
    """Display a histogram for a list `vals` """
    mean_val = statistics.mean(vals)
    print(f"Mean value: {mean_val}")
    sns.set(color_codes=True)
    sns.distplot(vals)
    plt.show()

def count(vals):
    """Display a count plot for a list `vals` (categorical data)"""
    sns.set(color_codes=True)
    sns.countplot(vals)
    plt.show()

def percentile(l, item):
    """find the percentile of an item based on a list"""
    return stats.percentileofscore(l, item)

# %% [markdown]
# ## Save and Load
# Sometimes you may want to save an API response after you've modified it or load it again later. These functions let you do that.

# %%
def save(filename, data):
    """Saves a file in the current directory"""
    if not os.path.exists(filename):
        open(filename, 'w').close()
    
    with open(filename, 'r+') as f:
        try:
            f.seek(0)
            f.write(json.dumps(data, indent=4))
        except:
            f.seek(0)
            if type(data) == str:
                f.write(data)
            else:
                print("Invalid data type")
                return
        f.truncate()

def load(filename):
    with open(filename, 'r+') as f:
        try:
            f.seek(0)
            data = json.load(f)
        except:
            f.seek(0)
            data = f.read()
        return data
